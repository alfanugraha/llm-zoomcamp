# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential

# Mengambil token dari environment variable
token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.github.ai/inference"

# Inisialisasi client
client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token)
)

# Panggil model (contoh: Meta Llama 3)
response = client.complete(
    messages=[
        {"role": "system", "content": "Kamu adalah asisten yang ramah."},
        {"role": "user", "content": "Jelaskan apa itu AI dalam 1 kalimat."},
    ],
    model="gpt-4o-mini"
    # temperature=0.7,
    # max_tokens=100
)

print(response.choices[0].message.content)
# Out:
# AI, atau kecerdasan buatan, adalah sistem komputer yang dirancang untuk meniru proses berpikir manusia, seperti pembelajaran, pemecahan masalah, dan pengambilan keputusan.
